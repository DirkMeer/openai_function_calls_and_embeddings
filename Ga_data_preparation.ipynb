# %%
import openai
import pandas as pd
import decouple

config = decouple.AutoConfig(" ")
openai.api_key = config("CHATGPT_API_KEY")
EMBEDDING_MODEL = "text-embedding-ada-002"
INPUT_DB_NAME = "Gx_reviews_database.csv"
OUTPUT_DB_NAME = "Gx_review_embeddings.csv"

# %%
df = pd.read_csv(INPUT_DB_NAME, usecols=["Summary", "Text", "Score"], nrows=500)
df = df[df["Score"] != 3]
df["Summ_and_Text"] = "Title: " + df["Summary"] + "; Content: " + df["Text"]
df.head(5)
# Out:
#    Score                Summary  \
# 0      5  Good Quality Dog Food
# 1      1      Not as Advertised
# 2      4  "Delight" says it all
# 3      2         Cough Medicine
# 4      5            Great taffy
#
#                                                 Text  \
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...
#
#                                        Summ_and_Text
# 0  Title: Good Quality Dog Food; Content: I have ...
# 1  Title: Not as Advertised; Content: Product arr...
# 2  Title: "Delight" says it all; Content: This is...
# 3  Title: Cough Medicine; Content: If you are loo...
# 4  Title: Great taffy; Content: Great taffy at a ...

# %%
total_token_usage = 0
embeddings_generated = 0
total_data_rows = df.shape[0]


def get_embedding(item):
    global total_token_usage, embeddings_generated
    response = openai.Embedding.create(
        model=EMBEDDING_MODEL,
        input=item,
    )
    tokens_used = response["usage"]["total_tokens"]
    total_token_usage += tokens_used
    embeddings_generated += 1
    if (embeddings_generated % 10) == 0:
        print(
            f"Generated {embeddings_generated} embeddings so far with a total of {total_token_usage} tokens used. ({int((embeddings_generated / total_data_rows) * 100)}%)"
        )
    return response['data'][0]['embedding']

# %%
df["Embedding"] = df.Summ_and_Text.apply(lambda item: get_embedding(item))

df.to_csv(OUTPUT_DB_NAME, index=False)

print(
    f"""
Generated {embeddings_generated} embeddings with a total of {total_token_usage} tokens used. (Done!)
Successfully saved embeddings to {OUTPUT_DB_NAME}.

    """
)

df.head(10)
# Out:
# Generated 10 embeddings so far with a total of 680 tokens used. (2%)
# Generated 20 embeddings so far with a total of 1531 tokens used. (4%)
# Generated 30 embeddings so far with a total of 2313 tokens used. (6%)
# Generated 40 embeddings so far with a total of 3559 tokens used. (8%)
# Generated 50 embeddings so far with a total of 4806 tokens used. (10%)
# Generated 60 embeddings so far with a total of 5567 tokens used. (12%)
# Generated 70 embeddings so far with a total of 6788 tokens used. (15%)
# Generated 80 embeddings so far with a total of 8079 tokens used. (17%)
# Generated 90 embeddings so far with a total of 9046 tokens used. (19%)
# Generated 100 embeddings so far with a total of 9809 tokens used. (21%)
# Generated 110 embeddings so far with a total of 11220 tokens used. (23%)
# Generated 120 embeddings so far with a total of 12171 tokens used. (25%)
# Generated 130 embeddings so far with a total of 12873 tokens used. (28%)
# Generated 140 embeddings so far with a total of 13764 tokens used. (30%)
# Generated 150 embeddings so far with a total of 14493 tokens used. (32%)
# Generated 160 embeddings so far with a total of 15498 tokens used. (34%)
# Generated 170 embeddings so far with a total of 16199 tokens used. (36%)
# Generated 180 embeddings so far with a total of 17432 tokens used. (38%)
# Generated 190 embeddings so far with a total of 18210 tokens used. (41%)
# Generated 200 embeddings so far with a total of 19971 tokens used. (43%)
# Generated 210 embeddings so far with a total of 20880 tokens used. (45%)
# Generated 220 embeddings so far with a total of 22247 tokens used. (47%)
# Generated 230 embeddings so far with a total of 23074 tokens used. (49%)
# Generated 240 embeddings so far with a total of 24340 tokens used. (51%)
# Generated 250 embeddings so far with a total of 25090 tokens used. (53%)
# Generated 260 embeddings so far with a total of 25874 tokens used. (56%)
# Generated 270 embeddings so far with a total of 27393 tokens used. (58%)
# Generated 280 embeddings so far with a total of 28424 tokens used. (60%)
# Generated 290 embeddings so far with a total of 29331 tokens used. (62%)
# Generated 300 embeddings so far with a total of 30016 tokens used. (64%)
# Generated 310 embeddings so far with a total of 30856 tokens used. (66%)
# Generated 320 embeddings so far with a total of 31614 tokens used. (69%)
# Generated 330 embeddings so far with a total of 32457 tokens used. (71%)
# Generated 340 embeddings so far with a total of 33628 tokens used. (73%)
# Generated 350 embeddings so far with a total of 34307 tokens used. (75%)
# Generated 360 embeddings so far with a total of 35389 tokens used. (77%)
# Generated 370 embeddings so far with a total of 36108 tokens used. (79%)
# Generated 380 embeddings so far with a total of 37060 tokens used. (82%)
# Generated 390 embeddings so far with a total of 37826 tokens used. (84%)
# Generated 400 embeddings so far with a total of 38976 tokens used. (86%)
# Generated 410 embeddings so far with a total of 39926 tokens used. (88%)
# Generated 420 embeddings so far with a total of 40927 tokens used. (90%)
# Generated 430 embeddings so far with a total of 41857 tokens used. (92%)
# Generated 440 embeddings so far with a total of 43278 tokens used. (95%)
# Generated 450 embeddings so far with a total of 43869 tokens used. (97%)
# Generated 460 embeddings so far with a total of 44676 tokens used. (99%)
#
# Generated 463 embeddings with a total of 45051 tokens used. (Done!)
# Successfully saved embeddings to Gx_review_embeddings.csv.
#    Score                                        Summary  \
# 0      5                          Good Quality Dog Food
# 1      1                              Not as Advertised
# 2      4                          "Delight" says it all
# 3      2                                 Cough Medicine
# 4      5                                    Great taffy
# 5      4                                     Nice Taffy
# 6      5  Great!  Just as good as the expensive brands!
# 7      5                         Wonderful, tasty taffy
# 8      5                                     Yay Barley
# 9      5                               Healthy Dog Food
#
#                                                 Text  \
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...
# 5  I got a wild hair for taffy and ordered this f...
# 6  This saltwater taffy had great flavors and was...
# 7  This taffy is so good.  It is very soft and ch...
# 8  Right now I'm mostly just sprouting this so my...
# 9  This is a very healthy dog food. Good for thei...
#
#                                        Summ_and_Text  \
# 0  Title: Good Quality Dog Food; Content: I have ...
# 1  Title: Not as Advertised; Content: Product arr...
# 2  Title: "Delight" says it all; Content: This is...
# 3  Title: Cough Medicine; Content: If you are loo...
# 4  Title: Great taffy; Content: Great taffy at a ...
# 5  Title: Nice Taffy; Content: I got a wild hair ...
# 6  Title: Great!  Just as good as the expensive b...
# 7  Title: Wonderful, tasty taffy; Content: This t...
# 8  Title: Yay Barley; Content: Right now I'm most...
# 9  Title: Healthy Dog Food; Content: This is a ve...
#
#                                            Embedding
# 0  [9.45914798649028e-05, 0.0025626542046666145, ...
# 1  [-0.010502041317522526, -0.005715508479624987,...
# 2  [0.0007722130976617336, 0.006629731971770525, ...
# 3  [0.010979381389915943, 0.01641949638724327, -0...
# 4  [-0.01659574918448925, -0.0036598483566194773,...
# 5  [-0.0024112274404615164, -0.003537999931722879...
# 6  [-0.0027381693944334984, -0.008508416824042797...
# 7  [-0.005907095968723297, -0.0032475811894983053...
# 8  [-0.007997295819222927, -0.011915299110114574,...
# 9  [0.0029935531783849, 0.005754504352807999, 0.0...
